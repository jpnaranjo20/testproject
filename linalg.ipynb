# %%
import numpy as np
import matplotlib.pyplot as plt


A = np.array([[2,1],[4,5]])
b = np.array([[3],[5]])

x = np.linalg.inv(A)*b
print(x)
# Out:
# [[ 2.5        -0.5       ]
#  [-3.33333333  1.66666667]]

# %%
t = np.linspace(1,50,1000)
l = np.sin(t)

plt.plot(t,l)
plt.title('$sin(x)$')
plt.xlabel('x')
plt.ylabel('y')
# Out:
# Text(0, 0.5, 'y')
